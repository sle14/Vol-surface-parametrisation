# %%
from jupyterthemes import jtplot
jtplot.style(theme="monokai",context="notebook",ticks=True,grid=True)
template,transparent = "plotly_dark","rgba(0,0,0,0)"
import optimiser
import grapher
import pricer
import query

df = query.get_frame("Calibration","select * from dbo.vols")
grapher.plot2d_fitted(df,"TotAtmVar","Tenor","Forward",2,100,1000)
# Out:
# <div>
#
#
#             <div id="6b55ffcd-a65c-4941-b291-05a5d7aa3524" class="plotly-graph-div" style="height:600px; width:1500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6b55ffcd-a65c-4941-b291-05a5d7aa3524")) {
#                     Plotly.newPlot(
#                         '6b55ffcd-a65c-4941-b291-05a5d7aa3524',
# ...

# %%
grapher.plot3d_quotes(df,"MidSpot","Moneyness","Vol",atm_plots=True,div_plot=True,payoff_plot=False,params_plot=True,z_col2="TotVar")
# Out:
# <div>
#
#
#             <div id="bb752f7a-811a-4c5e-a222-f210bae8731e" class="plotly-graph-div" style="height:700px; width:1500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb752f7a-811a-4c5e-a222-f210bae8731e")) {
#                     Plotly.newPlot(
#                         'bb752f7a-811a-4c5e-a222-f210bae8731e',
# ...

# %%
grapher.plot3d_boundaries(df,0)
# Out:
# <div>
#
#
#             <div id="6ad0321a-c894-4428-9e5f-4c9fb2e6a8c2" class="plotly-graph-div" style="height:700px; width:1500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6ad0321a-c894-4428-9e5f-4c9fb2e6a8c2")) {
#                     Plotly.newPlot(
#                         '6ad0321a-c894-4428-9e5f-4c9fb2e6a8c2',
# ...
